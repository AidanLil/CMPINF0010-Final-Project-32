# %% [markdown]
# Wilson's personal notebook
#
# Metric: Transportation
#
# Neighborhood borders: https://data.wprdc.org/dataset/neighborhoods2
# Transit stop locations: https://data.wprdc.org/dataset/port-authority-of-allegheny-county-transit-stops

# %%
# import libraries
import geopandas as gpd
import pandas as pd
from scipy import stats

# %%
# read neighborhood polygons
neighborhoods = gpd.read_file('https://data.wprdc.org/dataset/e672f13d-71c4-4a66-8f38-710e75ed80a4/resource/4af8e160-57e9-4ebf-a501-76ca1b42fc99/download/pittsburghpaneighborhoods-.geojson')

# Reproject hoods to match CRS with meters as base (so I can calculate per-km)
neighborhoods = neighborhoods.to_crs('+proj=cea +lat_0=40.440624 +lon_0=-79.995888 +units=m')

neighborhoods.head()
# Out:
#    objectid  fid_blockg statefp10 countyfp10 tractce10 blkgrpce10  \
# 0      1293         201        42        003    980600          1
# 1      1294          10        42        003    261200          1
# 2      1295          11        42        003    260900          1
# 3      1296           7        42        003    262000          1
# 4      1297           8        42        003    261500          1
#
#         geoid10     namelsad10 mtfcc10 funcstat10  ...  page_number  \
# 0  420039806001  Block Group 1   G5030          S  ...           15
# 1  420032612001  Block Group 1   G5030          S  ...           15
# 2  420032609001  Block Group 1   G5030          S  ...           15
# 3  420032620001  Block Group 1   G5030          S  ...           15
# 4  420032615001  Block Group 1   G5030          S  ...           15
#
#            plannerassign created_user         created_date  last_edited_user  \
# 0  Stephanie Joy Everett    pgh.admin  2020-08-14T14:52:26         pgh.admin
# 1  Stephanie Joy Everett    pgh.admin  2020-08-14T14:52:26         pgh.admin
# 2  Stephanie Joy Everett    pgh.admin  2020-08-14T14:52:26         pgh.admin
# 3  Stephanie Joy Everett    pgh.admin  2020-08-14T14:52:26         pgh.admin
# 4  Stephanie Joy Everett    pgh.admin  2020-08-14T14:52:26         pgh.admin
#
#       last_edited_date  temp   Shape__Area  Shape__Length  \
# 0  2020-08-14T14:52:26  None  1.068796e+07   19600.573085
# 1  2020-08-14T14:52:26  None  1.133208e+07   21174.473326
# 2  2020-08-14T14:52:26  None  8.743618e+06   13811.917169
# 3  2020-08-14T14:52:26  None  1.754935e+07   18197.745741
# 4  2020-08-14T14:52:26  None  2.522420e+07   26390.549314
#
#                                             geometry
# 0  POLYGON ((-3795.920 4118843.009, -3785.567 411...
# 1  POLYGON ((-1657.274 4122282.602, -1651.679 412...
# 2  POLYGON ((-821.954 4120841.104, -820.083 41208...
# 3  POLYGON ((-192.173 4120155.314, -191.926 41201...
# 4  POLYGON ((-2040.634 4120396.643, -2055.439 412...
#
# [5 rows x 39 columns]

# %%
# create hood buffers (expand the neighborhoods by 200m each since that better represents transit accessibility)
hoods_buffer = neighborhoods.assign(
  old_geom = neighborhoods['geometry'],
  geometry = lambda df: df['geometry'].map(lambda geom: geom.buffer(200))
).assign(
  buffer_area = lambda df: df['geometry'].map(lambda geom: geom.area)
)

# %%
# read bus stop points
stops = gpd.read_file('./wbiggs-data/paac_stops_1909/PAAC_Stops_1909.dbf')

# Reproject stops to match CRS with meters as base
stops = stops.to_crs('+proj=cea +lat_0=40.440624 +lon_0=-79.995888 +units=m')

#stops.head()

# %%
# Count stops per neighborhood
stops_hoods_join = gpd.sjoin(stops, hoods_buffer)

hoods_points = hoods_buffer.join(stops_hoods_join.groupby('index_right').size().rename('points'),how='left')

hoods_points['points'] = hoods_points['points'].fillna(0)

# Calculate density
hoods_points['count_per_sq_km'] = hoods_points['points'] / (hoods_points['buffer_area'] / 1000000)

hoods_points['buf_geom'] = hoods_points['geometry']
hoods_points['geometry'] = hoods_points['old_geom']

# %%
hoods_points.plot(column='count_per_sq_km')

# %%
# I want scores to be evenly distributed - "50" should be about average - so I'm going to transform this to a uniform density distribution
import seaborn as sns
import numpy as np

print(sns.__version__)
# Out:
# 0.11.2

# %%
s, loc, scale = stats.lognorm.fit(hoods_points['count_per_sq_km'])

countplot = sns.histplot(hoods_points['count_per_sq_km'], stat='density')

space = np.linspace(*countplot.get_xlim(),100)
countplot.plot(space, stats.lognorm.pdf(space, s, loc, scale))

# %%
transformed = stats.lognorm.cdf(hoods_points['count_per_sq_km'], s, loc, scale)

# It's now roughly more uniform
transformedplot = sns.histplot(transformed)
transformedplot.plot()
# Out:
# []

# %%
# since we want max to be 100
hoods_points['transit_score'] = transformed / transformed.max()

pd.set_option('max_row', None)

hoods_points = hoods_points.sort_values('transit_score', ascending = False)

hoods_points[['hood', 'transit_score']]
# Out:
# ---------------------------------------------------------------------------
# OptionError                               Traceback (most recent call last)
# <ipython-input-13-22ffaf62aeff> in <module>
#       2 hoods_points['transit_score'] = transformed / transformed.max()
#       3
# ----> 4 pd.set_option('max_row', None)
#       5
#       6 hoods_points = hoods_points.sort_values('transit_score', ascending = False)
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/_config/config.py in __call__(self, *args, **kwds)
#     254
#     255     def __call__(self, *args, **kwds):
# --> 256         return self.__func__(*args, **kwds)
#     257
#     258     @property
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/_config/config.py in _set_option(*args, **kwargs)
#     147
#     148     for k, v in zip(args[::2], args[1::2]):
# --> 149         key = _get_single_key(k, silent)
#     150
#     151         o = _get_registered_option(key)
#
# /opt/tljh/user/lib/python3.8/site-packages/pandas/_config/config.py in _get_single_key(pat, silent)
#     114         raise OptionError(f"No such keys(s): {repr(pat)}")
#     115     if len(keys) > 1:
# --> 116         raise OptionError("Pattern matched multiple keys")
#     117     key = keys[0]
#     118
#
# OptionError: 'Pattern matched multiple keys'

# %%
hoods_points.plot(column='transit_score')
