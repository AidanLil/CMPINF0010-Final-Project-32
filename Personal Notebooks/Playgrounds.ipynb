# %% [markdown]
# With the nicer weather coming around, I felt the urge to get more physical activity, and I recently discovered that playgrounds are an excelent and unique way to get exercise. A neighborhood with more playgrounds will be a healthier and therefore higher quality neighborhood.

# %%
import pandas as pd
import geopandas
import numpy as np

data = pd.read_csv("https://data.wprdc.org/datastore/dump/e39ef76e-0a11-47c8-a86f-a37f55db7a2b") # read in the playgrounds data
pd.set_option('display.max_rows', None)
pgCount = data.groupby('neighborhood').count()['id']
pgCount = pgCount.sort_values( ascending=False )

# %%
neighborhoods = geopandas.read_file("https://data.wprdc.org/dataset/e672f13d-71c4-4a66-8f38-710e75ed80a4/resource/c5a93a8e-03d7-4eb3-91a8-c6b7db0fa261/download/pittsburghpaneighborhoods-.zip") # read in the shapefile
pg_map = neighborhoods.merge(pgCount, how='left', left_on='hood', right_on='neighborhood')

# %%
pg_map.plot(column='id', # set the data to be used for coloring
               cmap='summer_r',              # choose a color palette
               edgecolor="black",        # outline the districts in black
               legend=True,              # show the legend
               legend_kwds={'label': "Number of Playgrounds"}, # label the legend
               figsize=(15, 10),         # set the size
               missing_kwds={"color": "lightgrey"} # set disctricts with no data to gray
               )

# %%
pgMin = pgCount.min()
pgMax = pgCount.max()

pgScores = (pgCount) / (pgMax)
pgScores
# Out:
# neighborhood
# Squirrel Hill South         1.00000
# East Liberty                0.81250
# Beechview                   0.65625
# Allegheny Center            0.46875
# South Side Slopes           0.43750
# Hazelwood                   0.40625
# Sheraden                    0.40625
# Elliott                     0.34375
# Beltzhoover                 0.31250
# Highland Park               0.31250
# Mount Washington            0.31250
# Squirrel Hill North         0.31250
# Garfield                    0.28125
# Regent Square               0.28125
# South Oakland               0.28125
# Lincoln Place               0.28125
# Brighton Heights            0.25000
# Crawford-Roberts            0.25000
# Fineview                    0.25000
# Troy Hill                   0.21875
# Bloomfield                  0.21875
# Brookline                   0.21875
# Carrick                     0.21875
# Greenfield                  0.21875
# Manchester                  0.21875
# Lincoln-Lemington-Belmar    0.18750
# Banksville                  0.18750
# Perry North                 0.18750
# Swisshelm Park              0.18750
# Crafton Heights             0.15625
# Upper Lawrenceville         0.15625
# Upper Hill                  0.15625
# South Side Flats            0.15625
# Windgap                     0.15625
# Morningside                 0.15625
# Shadyside                   0.15625
# Marshall-Shadeland          0.15625
# New Homestead               0.15625
# Allentown                   0.12500
# Polish Hill                 0.12500
# Central Northside           0.12500
# Oakwood                     0.12500
# Fairywood                   0.12500
# Duquesne Heights            0.12500
# Homewood West               0.12500
# Homewood North              0.12500
# Terrace Village             0.12500
# Spring Garden               0.09375
# Central Lawrenceville       0.09375
# Larimer                     0.09375
# Spring Hill-City View       0.09375
# Bedford Dwellings           0.09375
# West End                    0.09375
# Bon Air                     0.09375
# Stanton Heights             0.09375
# Point Breeze North          0.09375
# Perry South                 0.09375
# Hays                        0.09375
# East Allegheny              0.09375
# Middle Hill                 0.09375
# Esplen                      0.06250
# Central Oakland             0.06250
# Bluff                       0.06250
# Westwood                    0.06250
# East Carnegie               0.06250
# Lower Lawrenceville         0.06250
# West Oakland                0.03125
# Strip District              0.03125
# Name: id, dtype: float64
